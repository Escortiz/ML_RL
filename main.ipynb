# %% [markdown]
# # **PROJECT SETUP**

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/Escortiz/ML_RL.git
# Out:
# Cloning into 'ML_RL'...
# remote: Enumerating objects: 1045, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 1045 (delta 25), reused 5 (delta 4), pack-reused 999 (from 2)
# Receiving objects: 100% (1045/1045), 712.20 MiB | 18.11 MiB/s, done.
# Resolving deltas: 100% (247/247), done.

# %%
# %cd /content/ML_RL
# Out:
# /content/ML_RL

# %% [markdown]
# # **GIT PULL**

# %%
# %cd /content/ML_RL
# !git pull
# Out:
# /content/ML_RL
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 69 (delta 29), reused 59 (delta 23), pack-reused 0 (from 0)
# Unpacking objects: 100% (69/69), 24.84 KiB | 326.00 KiB/s, done.
# From https://github.com/Escortiz/ML_RL
#    e93243e..98aab4d  main       -> origin/main
# Updating e93243e..98aab4d
# Fast-forward
#  eomt/README.md       |   6 +-
#  eomt/inference.ipynb |  58 ++++++++++++--
#  main.ipynb           | 212 +++++++++++++++++++++++++++++++++++++++++----------
#  3 files changed, 223 insertions(+), 53 deletions(-)

# %% [markdown]
# # **DOWNLOAD DATASETS TRAINED**

# %%
#%cd /content/ML_RL/eomt/dataset_trained/
# Out:
# /content/ML_RL/eomt/dataset_trained

# %%
#!gdown --folder 1q2vHUzora2nP52fP50zmoQAykWuwoGav -O temp_download
#!mv temp_download/*.bin ./
#!rm -rf temp_download
# Out:
# Retrieving folder contents
# Retrieving folder 11uyQc6M8xDTGji1bltehx0wlylqA4isf Project Descriptions
# Processing file 1tq5F_j_8O2vlGWbkU1ayPjYvCml1VEwr ComprehensiveRoadScenesUnderstanding.pdf
# Processing file 1Vz08DHsP_mojpCTAQTR6NHVq-2rEqAZM MaskArchitectureAnomalySegmentation.pdf
# Processing file 1zcayoIIJztxKuHOIjmSjGoQBDy4RdETr Anomaly_Validation_Datasets.zip
# Processing file 1vSLNXzu3zCuJ7oeu_hSV7xVTJPUoXvH0 eomt_cityscapes.bin
# Processing file 13tCjPYFBVf43hS9SqODsKqGeGx2TsgzS eomt_coco.bin
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1tq5F_j_8O2vlGWbkU1ayPjYvCml1VEwr
# To: /content/ML_RL/eomt/dataset_trained/temp_download/Project Descriptions/ComprehensiveRoadScenesUnderstanding.pdf
# 100% 329k/329k [00:00<00:00, 122MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Vz08DHsP_mojpCTAQTR6NHVq-2rEqAZM
# ...

# %% [markdown]
# #**CITYSCAPES DOWNLOAD**

# %%
#%cd /content/ML_RL/cityscapes_dataset
# Out:
# /content/ML_RL/cityscapes_dataset

# %%
#!wget --keep-session-cookies --save-cookies=cookies.txt --post-data 'username=s347257@studenti.polito.it&password=<>&submit=Login' https://www.cityscapes-dataset.com/login/
#!wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=1
#!wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=3
# Out:
# --2026-06-26 10:33:04--  https://www.cityscapes-dataset.com/login/
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.cityscapes-dataset.com/downloads/ [following]
# --2026-06-26 10:33:05--  https://www.cityscapes-dataset.com/downloads/
# Reusing existing connection to www.cityscapes-dataset.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html’
#
# index.html              [  <=>               ]  55.82K   172KB/s    in 0.3s
#
# 2026-06-26 10:33:05 (172 KB/s) - ‘index.html’ saved [57162]
#
# --2026-06-26 10:33:05--  https://www.cityscapes-dataset.com/file-handling/?packageID=1
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# ...

# %% [markdown]
# # **EOMT SETUP**

# %%
# %cd /content/ML_RL/eomt
# Out:
# /content/ML_RL/eomt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 776.4 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.4/219.4 kB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 84.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 85.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 66.2 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall torch torchvision torchaudio -y
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# !python -c "import torch; print('GPU:', torch.cuda.is_available())"
# Out:
# Found existing installation: torch 2.7.0
# Uninstalling torch-2.7.0:
#   Successfully uninstalled torch-2.7.0
# Found existing installation: torchvision 0.22.0
# Uninstalling torchvision-0.22.0:
#   Successfully uninstalled torchvision-0.22.0
# Found existing installation: torchaudio 2.11.0+cu128
# Uninstalling torchaudio-2.11.0+cu128:
#   Successfully uninstalled torchaudio-2.11.0+cu128
# Looking in indexes: https://download.pytorch.org/whl/cu124
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...

# %%
# !pip install wandb
# !pip install --upgrade wandb
# !wandb login
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.8/26.8 MB 62.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.27.2
#     Uninstalling wandb-0.27.2:
#       Successfully uninstalled wandb-0.27.2
# ...
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: s347257 (s347257-politecnico-di-torino) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# ### **Training**

# %%
# %cd /content/ML_RL/eomt
# Out:
# /content/ML_RL/eomt

# %%
# !python main.py fit \
  -c configs/dinov2/cityscapes/semantic/eomt_base_640.yaml \
  --trainer.devices 1 \
  --data.batch_size 2 \
  --trainer.accumulate_grad_batches 8 \
  --data.path /content/ML_RL/cityscapes_dataset \
  --compile_disabled

  # To fine-tune a pre-trained EoMT model, add:
  # --model.ckpt_path /path/to/pytorch_model.bin \
  # --model.load_ckpt_class_head False
  # Replace /path/to/pytorch_model.bin with the path to
  # the checkpoint to fine-tune.
  # --model.load_ckpt_class_head False skips loading the
  # classification head when fine-tuning on a dataset with different classes.
# Out:
# 2026-05-20 15:12:54.236783: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Seed set to 0
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/vit_base_patch14_reg4_dinov2.lvd142m)
# INFO:timm.models._hub:[timm/vit_base_patch14_reg4_dinov2.lvd142m] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO:timm.layers.patch_embed:Resize patch embedding torch.Size([768, 3, 14, 14]) to (16, 16), w/ bicubic interpolation.
# INFO:timm.layers.pos_embed:Resized position embedding: (37, 37) to (64, 64).
# Using 16bit Automatic Mixed Precision (AMP)
# ...

# %%
# POINT 5: TRAINING WITH FINE-TUNING ON COCO VERSION

# !python main.py fit \
  -c /content/ML_RL/eomt/configs/dinov2/cityscapes/semantic/eomt_base_640.yaml \
  --trainer.devices 1 \
  --data.batch_size 4 \
  --trainer.accumulate_grad_batches 4 \
  --trainer.max_epochs 5 \
  --data.path /content/ML_RL/cityscapes_dataset \
  --data.init_args.img_size "[640, 640]" \
  --model.init_args.network.init_args.num_q 200 \
  --model.init_args.ckpt_path /content/ML_RL/eomt/dataset_trained/eomt_coco.bin \
  --model.init_args.load_ckpt_class_head False \
  --compile_disabled
# Out:
# 2026-06-03 16:51:15.577764: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Seed set to 0
# INFO:root:Loaded 195 keys
# Using 16bit Automatic Mixed Precision (AMP)
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# wandb: WARNING The anonymous setting has no effect and will be removed in a future version.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# ...

# %% [markdown]
# ### **Evaluating**

# %%
# VALIDATE FOR CITYSCAPES MODEL

# !python main.py validate \
  -c /content/ML_RL/eomt/configs/dinov2/cityscapes/semantic/eomt_base_640.yaml \
  --model.network.masked_attn_enabled False \
  --trainer.devices 1 \
  --data.batch_size 2 \
  --data.path /content/ML_RL/cityscapes_dataset \
  --model.ckpt_path /content/ML_RL/eomt/dataset_trained/eomt_cityscapes.bin

  # Replace /path/to/pytorch_model.bin with the path
  # to the checkpoint to evaluate.
# Out:
# 2026-06-10 09:00:51.869373: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Seed set to 0
# INFO:root:Loaded 197 keys
# Using 16bit Automatic Mixed Precision (AMP)
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# wandb: Currently logged in as: s347257 (s347257-politecnico-di-torino) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.10
# wandb: Run data is saved locally in ./wandb/run-20260610_090100-ckjhb5to
# ...

# %%
# VALIDATE FOR COCO MODEL

# !python main.py validate \
  -c /content/ML_RL/eomt/configs/dinov2/cityscapes/semantic/eomt_base_640.yaml \
  --model.init_args.network.init_args.masked_attn_enabled False \
  --trainer.devices 1 \
  --data.batch_size 2 \
  --data.path /content/ML_RL/cityscapes_dataset \
  --data.init_args.img_size "[640, 640]" \
  --model.init_args.network.init_args.num_q 200 \
  --data.init_args.num_classes 133 \
  --model.init_args.ckpt_path /content/ML_RL/eomt/dataset_trained/eomt_coco.bin
# Out:
# 2026-06-10 09:04:48.677928: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Seed set to 0
# INFO:root:Loaded 197 keys
# Using 16bit Automatic Mixed Precision (AMP)
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# wandb: Currently logged in as: s347257 (s347257-politecnico-di-torino) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.10
# wandb: Run data is saved locally in ./wandb/run-20260610_090457-xd7pzxgi
# ...

# %%
# POINT 5: VALIDATE AFTER FINE TUNING

# !python main.py validate \
  -c /content/ML_RL/eomt/configs/dinov2/cityscapes/semantic/eomt_base_640.yaml \
  --model.init_args.network.init_args.masked_attn_enabled False \
  --trainer.devices 1 \
  --data.batch_size 2 \
  --data.path /content/ML_RL/cityscapes_dataset \
  --model.init_args.ckpt_path "/content/ML_RL/eomt/dataset_trained/model.ckpt" \
  --data.init_args.img_size "[640, 640]" \
  --model.init_args.network.init_args.num_q 200 \
  --compile_disabled
# Out:
# 2026-06-10 09:08:22.305973: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Seed set to 0
# INFO:root:Loaded 197 keys
# Using 16bit Automatic Mixed Precision (AMP)
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# wandb: Currently logged in as: s347257 (s347257-politecnico-di-torino) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.10
# wandb: Run data is saved locally in ./wandb/run-20260610_090833-ct08esya
# ...

# %% [markdown]
# # **EVAL SETUP**

# %% [markdown]
# ### **ANOMALY VALIDATION DATASETS**

# %%
#%cd /content/ML_RL/anomaly_validation_datasets
# Out:
# /content/ML_RL/anomaly_validation_datasets

# %%
#!gdown "1zcayoIIJztxKuHOIjmSjGoQBDy4RdETr" -O Anomaly_Validation_Datasets.zip
#!unzip -q Anomaly_Validation_Datasets.zip
#!rm Anomaly_Validation_Datasets.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1zcayoIIJztxKuHOIjmSjGoQBDy4RdETr
# From (redirected): https://drive.google.com/uc?id=1zcayoIIJztxKuHOIjmSjGoQBDy4RdETr&confirm=t&uuid=85851794-1960-428b-876c-669125cef89a
# To: /content/ML_RL/anomaly_validation_datasets/Anomaly_Validation_Datasets.zip
# 100% 329M/329M [00:13<00:00, 25.2MB/s]

# %% [markdown]
# ### **CODE EVAL**

# %%
# %cd /content/ML_RL/eval
# Out:
# /content/ML_RL/eval

# %%
# !pip install ood_metrics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 105.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# %cd /content/ML_RL/eval
import ood_metrics
# Out:
# /content/ML_RL/eval

# %%
# This is the main test. It's used to see if the model recognizes things it never saw in training.
# !python evalAnomaly.py --input "/content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/*.png"

# %%
# POINT 7: MAX LOGIT, MSP AND MAX ENTROPY (MUST TEST IMAGES IN EACH DIRECTORY INSIDE VALIDATION_DATASET)

# Test Max Logit
# !python evalAnomaly.py \
  --input "/content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/*.png" \
  --method max_logit

# Test MSP
# !python evalAnomaly.py \
  --input "/content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/*.png" \
  --method msp

# Test Max Entropy
# !python evalAnomaly.py \
  --input "/content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/*.png" \
  --method max_entropy
# Out:
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/8.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/4.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/1.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/9.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/5.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/2.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/6.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/3.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/0.png
# ...

# %%
import wandb
wandb.login()

api = wandb.Api()
percorso_wandb = "s347257-politecnico-di-torino/Cityscapes_FineTuning/model-hkbf55lg:v4"

artifact = api.artifact(percorso_wandb)
artifact.download('/content/ML_RL/eomt/dataset_trained')
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: s347257 (s347257-politecnico-di-torino) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Downloading large artifact 'model-hkbf55lg:v4', 1071.15MB. 1 files...
# wandb:   1 of 1 files downloaded.
# Done. 00:01:13.5 (14.6MB/s)
# '/content/ML_RL/eomt/dataset_trained'

# %%
# POINT 8

import os
from pathlib import Path

dataset_base_path = "/content/ML_RL/anomaly_validation_datasets/Validation_Dataset"
script_name = "/content/ML_RL/eval/evalAnomalyEomt.py"

models = {
    "COCO": {
        "model_name": "coco",
        "weights": "/content/ML_RL/eomt/dataset_trained/eomt_coco.bin",
        "config": "/content/ML_RL/eomt/configs/dinov2/cityscapes/semantic/eomt_base_640.yaml"
    }#,
    #"Cityscapes": {
     #   "model_name": "cityscapes",
      #  "weights": "/content/ML_RL/eomt/dataset_trained/eomt_cityscapes.bin",
       # "config": "/content/ML_RL/eomt/configs/dinov2/cityscapes/semantic/eomt_base_640.yaml"
    #},
    #"FineTuned": {
     #   "model_name": "finetuned",
      #  "weights": "/content/ML_RL/eomt/dataset_trained/model.ckpt",
       # "config": "/content/ML_RL/eomt/configs/dinov2/cityscapes/semantic/eomt_base_640.yaml"
    #}
}

methods = ["msp", "max_logit", "max_entropy", "rba"]
dataset_dirs = [d for d in os.listdir(dataset_base_path) if os.path.isdir(os.path.join(dataset_base_path, d))]

# %cd /content/ML_RL/eomt

for current_model, info in models.items():
    print(f" START CHECKPOINT EVALUATION: {current_model.upper()} ")

    for dataset in dataset_dirs:
        input_path = f"{dataset_base_path}/{dataset}/images/*"

        for method in methods:
            print(f"\n[Normal Test] Dataset: {dataset} | Model: {current_model} | Method: {method}")

            command = f"python {script_name} --input \"{input_path}\" --loadWeights \"{info['weights']}\" --config \"{info['config']}\" --method \"{method}\" --model_name \"{info['model_name']}\""

            if current_model == "Cityscapes":
                command += " --num_q 100"

            # !{command}

            if current_model == 'FineTuned' and method == 'msp':
                temperatures = [0.5, 0.75, 1.1]
                for T in temperatures:
                    print(f"\n[Temperature Test] Dataset: {dataset} | Method: MSP(t={T})")
                    command_t = command + f" --temperature {T}"
                    # !{command_t}
# Out:
# /content/ML_RL/eomt
#  START CHECKPOINT EVALUATION: COCO
#
# [Normal Test] Dataset: FS_LostFound_full | Model: COCO | Method: msp
# ...
# [MSP] AUPRC score: 1.3399423945% | FPR@TPR95: 95.3282085382%
#
# [Normal Test] Dataset: FS_LostFound_full | Model: COCO | Method: max_logit
# ...
# [MAX_LOGIT] AUPRC score: 10.1474625242% | FPR@TPR95: 69.1302175238%
#
# [Normal Test] Dataset: FS_LostFound_full | Model: COCO | Method: max_entropy
# ...
# [MAX_ENTROPY] AUPRC score: 18.4376829224% | FPR@TPR95: 59.8421540966%
#
# [Normal Test] Dataset: FS_LostFound_full | Model: COCO | Method: rba
# ...
# [RBA] AUPRC score: 0.2294810557% | FPR@TPR95: 95.8147271361%
#
# [Normal Test] Dataset: RoadAnomaly | Model: COCO | Method: msp
# ...
# [MSP] AUPRC score: 21.9428604085% | FPR@TPR95: 93.1627271838%
#
# [Normal Test] Dataset: RoadAnomaly | Model: COCO | Method: max_logit
# ...
# [MAX_LOGIT] AUPRC score: 22.0392017190% | FPR@TPR95: 89.8488992226%
#
# [Normal Test] Dataset: RoadAnomaly | Model: COCO | Method: max_entropy
# ...

# %%
# This script takes the validation images, passes them to the model,
# and saves color images (inside the eval/save_color/ folder)
# !python eval_cityscapes_color.py \
  --datadir /content/ML_RL/cityscapes_dataset \
  --subset val \
  --num-workers 2
# Out:
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/ML_RL/cityscapes_dataset/leftImg8bit/val /content/ML_RL/cityscapes_dataset/gtFine/val

# %%
# This script returns a mathematical score. It calculates the mIoU (Mean Intersection over Union) metric
# to tell you exactly how accurate the model is on Cityscapes' roads.
# !python eval_iou.py \
  --datadir /content/ML_RL/cityscapes_dataset \
  --subset val \
  --num-workers 2
# Out:
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/ML_RL/cityscapes_dataset/leftImg8bit/val /content/ML_RL/cityscapes_dataset/gtFine/val
# ---------------------------------------
# Took  0.04284024238586426 seconds
# ...
# Per-Class IoU:
# 0.00 Road
# 0.00 sidewalk
# 0.00 building
# 0.00 wall
# 0.00 fence
# 0.00 pole
# 0.00 traffic light
# 0.00 traffic sign
# 0.00 vegetation
# 0.00 terrain
# 0.00 sky
# 0.00 person
# 0.00 rider
# 0.00 car
# 0.00 truck
# 0.00 bus
# 0.00 train
# 0.00 motorcycle
# 0.00 bicycle
# ...
# MEAN IoU:  0.00 %

# %%
# It doesn't measure accuracy, but rather measures how many milliseconds it takes the model
# to process a single image of a given resolution.
# !python eval_forwardTime.py --width 1024 --height 512
# Out:
# Forward time per img (b=1): 0.021 (Mean: 0.021)
# Forward time per img (b=1): 0.039 (Mean: 0.030)
# Forward time per img (b=1): 0.039 (Mean: 0.033)
# Forward time per img (b=1): 0.039 (Mean: 0.034)
# Forward time per img (b=1): 0.039 (Mean: 0.035)
# Forward time per img (b=1): 0.039 (Mean: 0.036)
# Traceback (most recent call last):
#   File "/content/ML_RL/eval/eval_forwardTime.py", line 70, in <module>
#   File "/content/ML_RL/eval/eval_forwardTime.py", line 58, in main
#     time.sleep(1)   #to avoid overheating the GPU too much
#     ^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %%
# This script formats the results in a specific way (converting trainIds to labelIds) that's only
# required if you want to submit your results to the official Cityscapes servers to participate in
# the global leaderboards (probably not needed).
# !python eval_cityscapes_server.py \
  --datadir /content/ML_RL/cityscapes_dataset \
  --subset val \
  --num-workers 2
# Out:
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/ML_RL/cityscapes_dataset/leftImg8bit/val /content/ML_RL/cityscapes_dataset/gtFine/val

# %% [markdown]
# # **GIT COMMIT & PUSH**

# %%
# %cd /content/ML_RL
# !ls
# Out:
# /content/ML_RL
# anomaly_validation_datasets  eomt  main.ipynb  results_evalAnomalyEomt.txt
# cityscapes_dataset	     eval  README.md   trained_models

# %%
# --- IMPORTANT: CREATE TOKEN IN GITHUB ---
# 1. Settings
# 2. Find the Developer options (last option)
# 3. Choose Classic Tokens in the left menu
# 4. Generate the Token: Personal access token -> Token (Classic) -> Generate new token (classic)
# 5. In Select scopes section pick only the repo section
# 6. Save it (you won't see it again)

import getpass
import os

# --- ENTER YOUR INFORMATION HERE ---
NOME_UTENTE_GITHUB = ""
EMAIL_GITHUB = ""
NOME_PROPRIETARIO_REPO = "Escortiz" # DON'T CHANGE
NOME_REPO = "ML_RL" # DON'T CHANGE

print("Paste your GitHub Token:")
TOKEN = getpass.getpass()

REPO_URL_SICURO = f"https://{NOME_UTENTE_GITHUB}:{TOKEN}@github.com/{NOME_PROPRIETARIO_REPO}/{NOME_REPO}.git"

print("\nConfiguring Git...")
# !git config --global user.name "{NOME_UTENTE_GITHUB}"
# !git config --global user.email "{EMAIL_GITHUB}"

print("\nAdding modified files...")
# !git add .

# --- CHANGE COMMIT MESSAGE EVERY TIME ---
print("\nCreating commit...")
# !git commit -m "Fixed points 8."

print("\nPushing to GitHub...")
# !git remote set-url origin {REPO_URL_SICURO}
# !git push origin main

print("\nDone! Changes successfully submitted.")
# Out:
# Paste your GitHub Token:
# ··········
#
# Configuring Git...
#
# Adding modified files...
#
# Creating commit...
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
#
# Pushing to GitHub...
# To https://github.com/Escortiz/ML_RL.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/Escortiz/ML_RL.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
#
# Done! Changes successfully submitted.

# %% [markdown]
# # **INFERENCE.IPYNB**

# %%
# %cd /content/ML_RL/eomt
# Out:
# /content/ML_RL/eomt

# %% [markdown]
# ### **Setup**

# %%
import yaml
from lightning import seed_everything
import torch
from torch.nn import functional as F
from torch.amp.autocast_mode import autocast
import matplotlib.pyplot as plt
import numpy as np
from huggingface_hub import hf_hub_download
from huggingface_hub.utils import RepositoryNotFoundError
import warnings
import importlib

seed_everything(0, verbose=False)

device = 0  # TODO: change to the GPU you want to use
img_idx = 5  # TODO: change to the index of the image you want to visualize
config_path = "/content/ML_RL/eomt/configs/dinov2/cityscapes/semantic/eomt_base_640.yaml"  # TODO: change to the config file
#config_path = "/content/ML_RL/eomt/configs/dinov2/coco/panoptic/eomt_base_640_2x.yaml"
data_path = "/content/ML_RL/cityscapes_dataset"  # TODO: change to the dataset directory
with open(config_path, "r") as f:
    config = yaml.safe_load(f)


def create_mapping(images, ignore_index):
    unique_ids = np.unique(np.concatenate([np.unique(img) for img in images]))
    valid_ids = unique_ids[unique_ids != ignore_index]
    colors = np.array(
        [plt.cm.hsv(i / len(valid_ids))[:3] for i in range(len(valid_ids))]
    )
    mapping = {cid: colors[i] for i, cid in enumerate(valid_ids)}
    mapping[ignore_index] = np.array([0, 0, 0])
    return mapping


def apply_colormap(image, mapping):
    colored_image = np.zeros((*image.shape, 3))
    for cid in np.unique(image):
        colored_image[image == cid] = mapping.get(cid, [0, 0, 0])
    return colored_image

# %% [markdown]
# ### **Load dataset**
# Ensure the dataset files are correctly prepared and placed in the folder specified by data_path.

# %%
data_module_name, class_name = config["data"]["class_path"].rsplit(".", 1)
data_module = getattr(importlib.import_module(data_module_name), class_name)
data_module_kwargs = config["data"].get("init_args", {})

data = data_module(
    path=data_path,
    batch_size=1,
    check_empty_targets=False,
    **data_module_kwargs
).setup()

# %% [markdown]
# ### **Load model**

# %%
warnings.filterwarnings(
    "ignore",
    message=r".*Attribute 'network' is an instance of `nn\.Module` and is already saved during checkpointing.*",
)

# Load encoder
encoder_cfg = config["model"]["init_args"]["network"]["init_args"]["encoder"]
encoder_module_name, encoder_class_name = encoder_cfg["class_path"].rsplit(".", 1)
encoder_cls = getattr(importlib.import_module(encoder_module_name), encoder_class_name)
encoder = encoder_cls(img_size=data.img_size, **encoder_cfg.get("init_args", {}))

# Load network
network_cfg = config["model"]["init_args"]["network"]
network_module_name, network_class_name = network_cfg["class_path"].rsplit(".", 1)
network_cls = getattr(importlib.import_module(network_module_name), network_class_name)
network_kwargs = {k: v for k, v in network_cfg["init_args"].items() if k != "encoder"}
network = network_cls(
    masked_attn_enabled=False,
    num_classes=data.num_classes,
    encoder=encoder,
    **network_kwargs,
)

# Load Lightning module
lit_module_name, lit_class_name = config["model"]["class_path"].rsplit(".", 1)
lit_cls = getattr(importlib.import_module(lit_module_name), lit_class_name)
model_kwargs = {k: v for k, v in config["model"]["init_args"].items() if k != "network"}
if "stuff_classes" in config["data"].get("init_args", {}):
    model_kwargs["stuff_classes"] = config["data"]["init_args"]["stuff_classes"]

model = (
    lit_cls(
        img_size=data.img_size,
        num_classes=data.num_classes,
        network=network,
        **model_kwargs,
    )
    .eval()
    .to(device)
)
state_dict_path = "/content/ML_RL/eomt/dataset_trained/eomt_cityscapes.bin"
#state_dict_path = "/content/ML_RL/eomt/dataset_trained/eomt_coco.bin"

state_dict = torch.load(state_dict_path, map_location=f"cuda:{device}", weights_only=False)

if "state_dict" in state_dict:
    state_dict = state_dict["state_dict"]

model.load_state_dict(state_dict, strict=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# <All keys matched successfully>

# %% [markdown]
# ### **Semantic inference (pixel-wise classification)**

# %%
IGNORE_INDEX = 255


def infer_semantic(img, target):
    with torch.no_grad(), autocast(dtype=torch.float16, device_type="cuda"):
        imgs = [img.to(device)]
        img_sizes = [img.shape[-2:] for img in imgs]
        crops, origins = model.window_imgs_semantic(imgs)

        mask_logits_per_layer, class_logits_per_layer = model(crops)
        mask_logits = F.interpolate(
            mask_logits_per_layer[-1], data.img_size, mode="bilinear"
        )

        crop_logits = model.to_per_pixel_logits_semantic(
            mask_logits, class_logits_per_layer[-1]
        )
        logits = model.revert_window_logits_semantic(crop_logits, origins, img_sizes)
        preds = logits[0].argmax(0).cpu()

    pred_array = preds.numpy()
    target_array = model.to_per_pixel_targets_semantic([target], IGNORE_INDEX)[
        0
    ].numpy()
    return pred_array, target_array


def plot_semantic_results(img, pred_array, target_array):
    mapping = create_mapping([pred_array, target_array], IGNORE_INDEX)

    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    axes[0].imshow(img.permute(1, 2, 0).cpu().numpy())
    axes[0].set_title("Image")
    axes[1].imshow(apply_colormap(pred_array, mapping))
    axes[1].set_title("Prediction")
    axes[2].imshow(apply_colormap(target_array, mapping))
    axes[2].set_title("Target")

    for ax in axes:
        ax.axis("off")

    plt.tight_layout()
    plt.show()


img, target = data.val_dataloader().dataset[img_idx]
pred_array, target_array = infer_semantic(img, target)
plot_semantic_results(img, pred_array, target_array)

# %% [markdown]
# ### **Panoptic inference (segmentation with instance IDs)**

# %%
def infer_panoptic(img, target):
    with torch.no_grad(), autocast(dtype=torch.float16, device_type="cuda"):
        imgs = [img.to(device)]
        img_sizes = [img.shape[-2:] for img in imgs]

        transformed_imgs = model.resize_and_pad_imgs_instance_panoptic(imgs)
        mask_logits_per_layer, class_logits_per_layer = model(transformed_imgs)
        mask_logits = F.interpolate(
            mask_logits_per_layer[-1], model.img_size, mode="bilinear"
        )
        mask_logits = model.revert_resize_and_pad_logits_instance_panoptic(
            mask_logits, img_sizes
        )

        preds = model.to_per_pixel_preds_panoptic(
            mask_logits,
            class_logits_per_layer[-1],
            model.stuff_classes,
            model.mask_thresh,
            model.overlap_thresh,
        )[0].cpu()

    pred = preds.numpy()
    sem_pred, inst_pred = pred[..., 0], pred[..., 1]

    target_seg = model.to_per_pixel_targets_panoptic([target])[0].cpu().numpy()
    sem_target, inst_target = target_seg[..., 0], target_seg[..., 1]

    return sem_pred, inst_pred, sem_target, inst_target


def draw_black_border(sem, inst, mapping):
    h, w = sem.shape
    out = np.zeros((h, w, 3))
    for s in np.unique(sem):
        out[sem == s] = mapping[s]

    combined = sem.astype(np.int64) * 100000 + inst.astype(np.int64)
    border = np.zeros((h, w), dtype=bool)
    border[1:, :] |= combined[1:, :] != combined[:-1, :]
    border[:-1, :] |= combined[1:, :] != combined[:-1, :]
    border[:, 1:] |= combined[:, 1:] != combined[:, :-1]
    border[:, :-1] |= combined[:, 1:] != combined[:, :-1]
    out[border] = 0
    return out


def plot_panoptic_results(img, sem_pred, inst_pred, sem_target, inst_target):
    all_ids = np.union1d(np.unique(sem_pred), np.unique(sem_target))
    mapping = {
        s: (
            [0, 0, 0]
            if s == -1 or s == model.num_classes
            else plt.cm.hsv(i / len(all_ids))[:3]
        )
        for i, s in enumerate(all_ids)
    }

    vis_pred = draw_black_border(sem_pred, inst_pred, mapping)
    vis_target = draw_black_border(sem_target, inst_target, mapping)

    img_np = (
        img.cpu().numpy().transpose(1, 2, 0) if img.dim() == 3 else img.cpu().numpy()
    )

    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    axes[0].imshow(img_np)
    axes[0].set_title("Input")
    axes[1].imshow(vis_pred)
    axes[1].set_title("Prediction")
    axes[2].imshow(vis_target)
    axes[2].set_title("Target")

    for ax in axes:
        ax.axis("off")

    plt.tight_layout()
    plt.show()


img, target = data.val_dataloader().dataset[img_idx]
sem_pred, inst_pred, sem_target, inst_target = infer_panoptic(img, target)
plot_panoptic_results(img, sem_pred, inst_pred, sem_target, inst_target)

# %% [markdown]
# ### **Code that works for both**

# %%
# FASE A: CITYSCAPES (Semantic)
#ACTIVE_YAML = "/content/ML_RL/eomt/configs/dinov2/cityscapes/semantic/eomt_base_640.yaml"
#ACTIVE_WEIGHTS = "/content/ML_RL/eomt/dataset_trained/eomt_cityscapes.bin"

# FASE B: COCO (Panoptic)
ACTIVE_YAML = "/content/ML_RL/eomt/configs/dinov2/coco/panoptic/eomt_base_640_2x.yaml"
ACTIVE_WEIGHTS = "/content/ML_RL/eomt/dataset_trained/eomt_coco.bin"

data_path = "/content/ML_RL/cityscapes_dataset"

with open(ACTIVE_YAML, "r") as f:
    model_config = yaml.safe_load(f)

# Always forcefully read the Cityscapes config for the data part
with open("/content/ML_RL/eomt/configs/dinov2/cityscapes/semantic/eomt_base_640.yaml", "r") as f:
    data_config = yaml.safe_load(f)

# DATASET LOADING (Cityscapes)
data_module_name, class_name = data_config["data"]["class_path"].rsplit(".", 1)
data_module = getattr(importlib.import_module(data_module_name), class_name)
data_module_kwargs = data_config["data"].get("init_args", {})

data = data_module(
    path=data_path,
    batch_size=1,
    check_empty_targets=False,
    **data_module_kwargs
).setup()

# MODEL BUILDING (Adaptive for COCO or Cityscapes)
warnings.filterwarnings("ignore", message=r".*Attribute 'network'.*")

# Figure out how many classes we need and set the size to 640x640 for preventing black screen
is_coco = "coco" in ACTIVE_YAML
model_num_classes = 133 if is_coco else 19
model_img_size = (640, 640) if is_coco else data.img_size

# Load encoder
encoder_cfg = model_config["model"]["init_args"]["network"]["init_args"]["encoder"]
encoder_module_name, encoder_class_name = encoder_cfg["class_path"].rsplit(".", 1)
encoder_cls = getattr(importlib.import_module(encoder_module_name), encoder_class_name)
encoder = encoder_cls(img_size=model_img_size, **encoder_cfg.get("init_args", {}))

# Load network
network_cfg = model_config["model"]["init_args"]["network"]
network_module_name, network_class_name = network_cfg["class_path"].rsplit(".", 1)
network_cls = getattr(importlib.import_module(network_module_name), network_class_name)
network_kwargs = {k: v for k, v in network_cfg["init_args"].items() if k != "encoder"}
network = network_cls(
    masked_attn_enabled=False,
    num_classes=model_num_classes, # Use the model's classes, not the dataset's!
    encoder=encoder,
    **network_kwargs,
)

# Load Lightning module
lit_module_name, lit_class_name = model_config["model"]["class_path"].rsplit(".", 1)
lit_cls = getattr(importlib.import_module(lit_module_name), lit_class_name)
model_kwargs = {k: v for k, v in model_config["model"]["init_args"].items() if k != "network"}
# Read "stuff_classes" from the Model (COCO) config
if "stuff_classes" in model_config["data"].get("init_args", {}):
    model_kwargs["stuff_classes"] = model_config["data"]["init_args"]["stuff_classes"]

model = (
    lit_cls(
        img_size=model_img_size,
        num_classes=model_num_classes,
        network=network,
        **model_kwargs,
    )
    .eval()
    .to(device)
)

# WEIGHT LOADING
state_dict = torch.load(ACTIVE_WEIGHTS, map_location=f"cuda:{device}", weights_only=False)

if "state_dict" in state_dict:
    state_dict = state_dict["state_dict"]

model.load_state_dict(state_dict, strict=False)
print(f"Modello caricato con successo per: {'COCO (Panottico)' if is_coco else 'Cityscapes (Semantico)'}")
# Out:
# Modello caricato con successo per: COCO (Panottico)
