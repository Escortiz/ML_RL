# %% [markdown]
# # **PROJECT SETUP**

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/Escortiz/ML_RL.git
# Out:
# Cloning into 'ML_RL'...
# remote: Enumerating objects: 854, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 854 (delta 25), reused 33 (delta 10), pack-reused 795 (from 1)
# Receiving objects: 100% (854/854), 340.95 MiB | 17.94 MiB/s, done.
# Resolving deltas: 100% (156/156), done.

# %%
# %cd /content/ML_RL
# Out:
# /content/ML_RL

# %% [markdown]
# # **GIT PULL**

# %%
# %cd /content/ML_RL
# !git pull
# Out:
# /content/ML_RL

# %% [markdown]
# # **DOWNLOAD DATASETS TRAINED**

# %%
# %cd /content/ML_RL/eomt/dataset_trained/
# Out:
# /content/ML_RL/eomt/dataset_trained

# %%
# !gdown --folder 1q2vHUzora2nP52fP50zmoQAykWuwoGav -O temp_download
# !mv temp_download/*.bin ./
# !rm -rf temp_download
# !ls -l
# Out:
# Retrieving folder contents
# Retrieving folder 11uyQc6M8xDTGji1bltehx0wlylqA4isf Project Descriptions
# Processing file 1tq5F_j_8O2vlGWbkU1ayPjYvCml1VEwr ComprehensiveRoadScenesUnderstanding.pdf
# Processing file 1Vz08DHsP_mojpCTAQTR6NHVq-2rEqAZM MaskArchitectureAnomalySegmentation.pdf
# Processing file 1zcayoIIJztxKuHOIjmSjGoQBDy4RdETr Anomaly_Validation_Datasets.zip
# Processing file 1vSLNXzu3zCuJ7oeu_hSV7xVTJPUoXvH0 eomt_cityscapes.bin
# Processing file 13tCjPYFBVf43hS9SqODsKqGeGx2TsgzS eomt_coco.bin
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1tq5F_j_8O2vlGWbkU1ayPjYvCml1VEwr
# To: /content/ML_RL/eomt/dataset_trained/temp_download/Project Descriptions/ComprehensiveRoadScenesUnderstanding.pdf
# 100% 329k/329k [00:00<00:00, 114MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Vz08DHsP_mojpCTAQTR6NHVq-2rEqAZM
# ...

# %% [markdown]
# #**CITYSCAPES DOWNLOAD**

# %%
#%cd /content/ML_RL/cityscapes_dataset
# Out:
# /content/ML_RL/cityscapes_dataset

# %%
#!wget --keep-session-cookies --save-cookies=cookies.txt --post-data 'username=<your_username>&password=<your_password>&submit=Login' https://www.cityscapes-dataset.com/login/
#!wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=1
#!wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=3
# Out:
# --2026-05-20 14:28:18--  https://www.cityscapes-dataset.com/login/
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.cityscapes-dataset.com/downloads/ [following]
# --2026-05-20 14:28:19--  https://www.cityscapes-dataset.com/downloads/
# Reusing existing connection to www.cityscapes-dataset.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html’
#
# index.html              [   <=>              ]  55.82K   136KB/s    in 0.4s
#
# 2026-05-20 14:28:20 (136 KB/s) - ‘index.html’ saved [57162]
#
# --2026-05-20 14:28:20--  https://www.cityscapes-dataset.com/file-handling/?packageID=1
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# ...

# %% [markdown]
# # **EOMT SETUP**

# %%
# %cd /content/ML_RL/eomt
# Out:
# /content/ML_RL/eomt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 809.7 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.4/219.4 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 37.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 104.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 50.7 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall torch torchvision torchaudio -y
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# !python -c "import torch; print('GPU:', torch.cuda.is_available())"
# Out:
# GPU: True

# %%
# !pip install wandb
# !pip install --upgrade wandb
# !wandb login
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.3/27.3 MB 50.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.19.10
#     Uninstalling wandb-0.19.10:
#       Successfully uninstalled wandb-0.19.10
# ...
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: s347257 (s347257-politecnico-di-torino) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# ### **Training**

# %%
# %cd /content/ML_RL/eomt
# Out:
# /content/ML_RL/eomt

# %%
# !python main.py fit \
  -c configs/dinov2/cityscapes/semantic/eomt_base_640.yaml \
  --trainer.devices 1 \
  --data.batch_size 2 \
  --trainer.accumulate_grad_batches 8 \
  --data.path /content/ML_RL/cityscapes_dataset \
  --compile_disabled

  # To fine-tune a pre-trained EoMT model, add:
  # --model.ckpt_path /path/to/pytorch_model.bin \
  # --model.load_ckpt_class_head False
  # Replace /path/to/pytorch_model.bin with the path to
  # the checkpoint to fine-tune.
  # --model.load_ckpt_class_head False skips loading the
  # classification head when fine-tuning on a dataset with different classes.
# Out:
# 2026-05-20 15:12:54.236783: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Seed set to 0
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/vit_base_patch14_reg4_dinov2.lvd142m)
# INFO:timm.models._hub:[timm/vit_base_patch14_reg4_dinov2.lvd142m] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO:timm.layers.patch_embed:Resize patch embedding torch.Size([768, 3, 14, 14]) to (16, 16), w/ bicubic interpolation.
# INFO:timm.layers.pos_embed:Resized position embedding: (37, 37) to (64, 64).
# Using 16bit Automatic Mixed Precision (AMP)
# ...

# %% [markdown]
# ### **Evaluating**

# %%
# !python main.py validate \
  -c configs/dinov2/coco/panoptic/eomt_large_640.yaml \
  --model.network.masked_attn_enabled False \
  --trainer.devices 1 \
  --data.batch_size 2 \
  --data.path /content/ML_RL/cityscapes_dataset \
  --model.ckpt_path /content/percorso_del_tuo_modello_scaricato.bin

  # Replace /path/to/pytorch_model.bin with the path
  # to the checkpoint to evaluate.

# %% [markdown]
# # **EVAL SETUP**

# %% [markdown]
# ### **ANOMALY VALIDATION DATASETS**

# %%
#%cd /content/ML_RL/anomaly_validation_datasets
# Out:
# /content/ML_RL/anomaly_validation_datasets

# %%
#!gdown "1zcayoIIJztxKuHOIjmSjGoQBDy4RdETr" -O Anomaly_Validation_Datasets.zip
#!unzip -q Anomaly_Validation_Datasets.zip
#!rm Anomaly_Validation_Datasets.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1zcayoIIJztxKuHOIjmSjGoQBDy4RdETr
# From (redirected): https://drive.google.com/uc?id=1zcayoIIJztxKuHOIjmSjGoQBDy4RdETr&confirm=t&uuid=fde44e8f-a082-476a-bde3-7406db3515df
# To: /content/ML_RL/anomaly_validation_datasets/Anomaly_Validation_Datasets.zip
# 100% 329M/329M [00:07<00:00, 44.5MB/s]

# %% [markdown]
# ### **CODE EVAL**

# %%
# %cd /content/ML_RL/eval
# Out:
# /content/ML_RL/eval

# %%
# !pip install ood_metrics

# %%
# %cd /content/ML_RL/eval
import ood_metrics
# Out:
# /content/ML_RL/eval

# %%
# This is the main test. It's used to see if the model recognizes things it never saw in training.
# !python evalAnomaly.py --input "/content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/*.png"
# Out:
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/4.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/0.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/5.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/9.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/2.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/7.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/1.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/3.png
# /content/ML_RL/anomaly_validation_datasets/Validation_Dataset/RoadAnomaly21/images/8.png
# ...

# %%
# This script takes the validation images, passes them to the model,
# and saves color images (inside the eval/save_color/ folder)
# !python eval_cityscapes_color.py \
  --datadir /content/ML_RL/cityscapes_dataset \
  --subset val \
  --num-workers 2
# Out:
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/ML_RL/cityscapes_dataset/leftImg8bit/val /content/ML_RL/cityscapes_dataset/gtFine/val

# %%
# This script returns a mathematical score. It calculates the mIoU (Mean Intersection over Union) metric
# to tell you exactly how accurate the model is on Cityscapes' roads.
# !python eval_iou.py \
  --datadir /content/ML_RL/cityscapes_dataset \
  --subset val \
  --num-workers 2
# Out:
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/ML_RL/cityscapes_dataset/leftImg8bit/val /content/ML_RL/cityscapes_dataset/gtFine/val
# ---------------------------------------
# Took  0.04284024238586426 seconds
# ...
# Per-Class IoU:
# 0.00 Road
# 0.00 sidewalk
# 0.00 building
# 0.00 wall
# 0.00 fence
# 0.00 pole
# 0.00 traffic light
# 0.00 traffic sign
# 0.00 vegetation
# 0.00 terrain
# 0.00 sky
# 0.00 person
# 0.00 rider
# 0.00 car
# 0.00 truck
# 0.00 bus
# 0.00 train
# 0.00 motorcycle
# 0.00 bicycle
# ...
# MEAN IoU:  0.00 %

# %%
# It doesn't measure accuracy, but rather measures how many milliseconds it takes the model
# to process a single image of a given resolution.
# !python eval_forwardTime.py --width 1024 --height 512
# Out:
# Forward time per img (b=1): 0.021 (Mean: 0.021)
# Forward time per img (b=1): 0.039 (Mean: 0.030)
# Forward time per img (b=1): 0.039 (Mean: 0.033)
# Forward time per img (b=1): 0.039 (Mean: 0.034)
# Forward time per img (b=1): 0.039 (Mean: 0.035)
# Forward time per img (b=1): 0.039 (Mean: 0.036)
# Traceback (most recent call last):
#   File "/content/ML_RL/eval/eval_forwardTime.py", line 70, in <module>
#   File "/content/ML_RL/eval/eval_forwardTime.py", line 58, in main
#     time.sleep(1)   #to avoid overheating the GPU too much
#     ^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %%
# This script formats the results in a specific way (converting trainIds to labelIds) that's only
# required if you want to submit your results to the official Cityscapes servers to participate in
# the global leaderboards (probably not needed).
# !python eval_cityscapes_server.py \
  --datadir /content/ML_RL/cityscapes_dataset \
  --subset val \
  --num-workers 2
# Out:
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/ML_RL/cityscapes_dataset/leftImg8bit/val /content/ML_RL/cityscapes_dataset/gtFine/val

# %% [markdown]
# # **GIT COMMIT & PUSH**

# %%
# %cd /content/ML_RL
# !ls
# Out:
# /content/ML_RL
# anomaly_validation_datasets  eomt  main.ipynb  trained_models
# cityscapes_dataset	     eval  README.md

# %%
# --- IMPORTANT: CREATE TOKEN IN GITHUB ---
# 1. Settings
# 2. Find the Developer options (last option)
# 3. Choose Classic Tokens in the left menu
# 4. Generate the Token: Personal access token -> Token (Classic) -> Generate new token (classic)
# 5. In Select scopes section pick only the repo section
# 6. Save it (you won't see it again)

import getpass
import os

# 1. Enter your information in plain text here
NOME_UTENTE_GITHUB = "SimoAsk793"
EMAIL_GITHUB = "simoneascheriii@gmail.com"
NOME_PROPRIETARIO_REPO = "Escortiz" # Don't change
NOME_REPO = "ML_RL" # Don't change

# 2. Secure Token Request
print("Paste your GitHub Token:")
TOKEN = getpass.getpass()

# Build the secure URL in memory
REPO_URL_SICURO = f"https://{NOME_UTENTE_GITHUB}:{TOKEN}@github.com/{NOME_PROPRIETARIO_REPO}/{NOME_REPO}.git"

# 3. Execute the commands Git
print("\nConfiguring Git...")
# !git config --global user.name "{NOME_UTENTE_GITHUB}"
# !git config --global user.email "{EMAIL_GITHUB}"

print("\nAdding modified files...")
# !git add .

# --- CHANGE COMMIT MESSAGE EVERY TIME ---
print("\nCreating commit...")
# !git commit -m "Update files and new directory"

print("\nPushing to GitHub...")
# !git remote set-url origin {REPO_URL_SICURO}
# !git push origin main

print("\nDone! Changes successfully submitted.")
# Out:
# Paste your GitHub Token:
# ··········
#
# Configuring Git...
#
# Adding modified files...
#
# Creating commit...
# [main e93243e] Update files and new directory
#  2 files changed, 4 insertions(+)
#  create mode 100644 eomt/dataset_trained/.gitignore
#  create mode 100644 eomt/dataset_trained/README.md
#
# Pushing to GitHub...
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 550 bytes | 550.00 KiB/s, done.
# Total 6 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/Escortiz/ML_RL.git
#    d6ca9dc..e93243e  main -> main
#
# Done! Changes successfully submitted.
